# %%
from cartopy import config
from matplotlib.pyplot import figure

import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.loadtxt('https://raw.githubusercontent.com/benjamin-hg-marchant/teaching/main/datasets/modis_myd06_cpop_2d_hist_1b1_grid.txt')

# %%
data
# Out:
# array([[0.06303943, 0.03444346, 0.03194341, ...,        nan,        nan,
#                nan],
#        [0.06826322, 0.0423479 , 0.0318004 , ...,        nan,        nan,
#                nan],
#        [0.07191781, 0.04401324, 0.03418141, ...,        nan,        nan,
#                nan],
#        ...,
#        [0.06777161, 0.03665244, 0.02831935, ...,        nan,        nan,
#                nan],
#        [0.05881109, 0.03645463, 0.029033  , ...,        nan,        nan,
#                nan],
#        [0.05840976, 0.03155711, 0.03003203, ...,        nan,        nan,
#                nan]])

# %%
data
# Out:
# array([[0.06303943, 0.03444346, 0.03194341, ...,        nan,        nan,
#                nan],
#        [0.06826322, 0.0423479 , 0.0318004 , ...,        nan,        nan,
#                nan],
#        [0.07191781, 0.04401324, 0.03418141, ...,        nan,        nan,
#                nan],
#        ...,
#        [0.06777161, 0.03665244, 0.02831935, ...,        nan,        nan,
#                nan],
#        [0.05881109, 0.03645463, 0.029033  , ...,        nan,        nan,
#                nan],
#        [0.05840976, 0.03155711, 0.03003203, ...,        nan,        nan,
#                nan]])

# %%
data[data == 0] = np.nan

plt.imshow(data.T, interpolation = 'none', vmin = 0)

# %%
fig = plt.figure(num=None, figsize=(8, 6), dpi=80, edgecolor='k')

ax = plt.axes(projection=ccrs.PlateCarree())

ax.coastlines()

plt.title("Plot a global map with cartopy in python", fontsize=12)
ax.imshow(data.T, origin='lower', extent=[-180,180,-90,90], transform=ccrs.PlateCarree(),cmap='jet',vmin=0, vmax=1.0)

plt.savefig("cartopy_heatmap.png", bbox_inches='tight', dpi=200)

plt
